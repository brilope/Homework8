# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
import pandas as pd

# %%
#load the dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(data = iris.data, columns = iris.feature_names)
iris_df['target'] = iris.target

# %%
#this will be a scatter plot
plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], c = iris_df['target'])
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.title('Sepal length vs Sepal width')
plt.show()

# %%
#this will be a bar plot
plt.bar(iris_df['target'], iris_df['sepal length (cm)'], color = 'purple')
plt.xlabel('target')
plt.ylabel('sepal length (cm)')
plt.title('Sepal length vs target')
plt.show()

# %%
#this will be a histogram
plt.hist(iris_df['sepal length (cm)'])
plt.xlabel('sepal length (cm)')
plt.ylabel('Frequency')
plt.title('Sepal length histogram')
plt.show()

# %%
#load the loan dataset from Kaggle
loan_data = "C:/Users/chemi/OneDrive/Coding/LoanDataset - LoansDatasest.csv"
loan_df = pd.read_csv(loan_data)

# %%
#this will be a bar plot
loan_df['Current_loan_status'].value_counts().plot(kind='bar', color='green') 
plt.title('Distribution of Loan Statuses') 
plt.xlabel('Loan Status') 
plt.ylabel('Count') 
plt.show()

# %%
# Plot the scatter plot
ax = fig.add_axes([0,0,1,1])
plt.scatter(loan_df['loan_amnt'], loan_df['term_years'], color='red')
plt.xlabel('Loan Amount')
plt.ylabel('Term Years')
plt.title('Loan Amount vs Term Years')
plt.show()

# %%
# Remove NaN values from 'loan_amnt' column
loan_df = loan_df.dropna(subset=['loan_amnt'])

# Plot the histogram
plt.hist(loan_df['loan_amnt'], color='green')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.title('Loan Amount Histogram')
plt.show()

# %%
#based on the plots, we can see that the loan amount is not normally distributed between the term years and loan amount. You can see this with the scatter plot and the histogram. The bar plot shows the distribution of loan statuses.
